# %% [markdown]
# <a href="https://colab.research.google.com/github/Waleed776-zoi/Image-Forgery-Detection/blob/main/RAG_application_with_Gemini_using_Langchain_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q --upgrade google-generativeai langchain-google-genai chromadb pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.9 MB/s eta 0:00:00
# ...

# %%
from IPython.display import display
from IPython.display import Markdown
import textwrap


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import google.generativeai as genai
from google.colab import userdata

# %%
import os
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel(model_name = "gemini-pro")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response = model.generate_content("What are the disadvantages of LLMs?")

# %%
to_markdown(response.text)
# Out:
# > **Bias and Discrimination:**
# >
# > * LLMs can perpetuate biases and discrimination present in their training data, leading to unfair or exclusionary results.
# > * They may reflect societal biases, such as racial, gender, or cultural prejudices, in their responses.
# >
# > **Lack of Context and Critical Thinking:**
# >
# > * LLMs are unable to fully grasp the context and nuances of human language, leading to superficial or irrelevant responses.
# > * They cannot engage in critical thinking or make informed judgments, relying solely on statistical patterns and correlations.
# >
# > **Factual Inaccuracy and Falsehoods:**
# >
# > * Due to their large but imperfect training datasets, LLMs may generate factually inaccurate or even false information.
# > * They can spread misinformation and reinforce conspiracy theories, particularly if they encounter biased or untrustworthy sources.
# >
# > **Lack of Transparency and Explainability:**
# >
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro",google_api_key=GOOGLE_API_KEY)

# %%
result = llm.invoke("What are the disadvantages of LLMs?")

# %%
to_markdown(result.content)
# Out:
# > **Bias and Discrimination:**
# >
# > * LLMs inherit biases from their training data, which can lead to unfair or discriminatory outputs.
# > * They may perpetuate stereotypes, reinforce existing prejudices, or produce offensive or harmful content.
# >
# > **Accuracy and Reliability:**
# >
# > * LLMs are trained on vast amounts of data, but their outputs may not always be accurate or reliable.
# > * They can generate plausible but incorrect or misleading information, especially when dealing with complex or abstract concepts.
# >
# > **Lack of Common Sense and Reasoning:**
# >
# > * LLMs are powerful text generators but lack the ability to understand context or reason logically.
# > * They may produce nonsensical or incoherent outputs, especially in situations that require real-world knowledge or inferential reasoning.
# >
# > **Contextual Limitations:**
# >
# ...

# %%
import PIL.Image

img = PIL.Image.open('image.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the LLM with a supported model
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", google_api_key=GOOGLE_API_KEY)

# Example usage
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "Write a short description about the product shown in the image for mentioning it on a gaming website.",
        },
        {"type": "image_url", "image_url": "/content/image.jpg"},
    ]
)

# Invoke the model
response = llm.invoke([message])

# Output the response
print(response)
# Out:
# content='Hitman: Sniper Assassin is a first-person shooter game where you play as Agent 47, a genetically engineered assassin. You must use your skills to take down targets from afar using a variety of sniper rifles. The game features a variety of levels, each with its own unique challenges and objectives.  \n' response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-1a7ffd58-95a8-4d92-83ce-83ea71ad09d2-0' usage_metadata={'input_tokens': 278, 'output_tokens': 61, 'total_tokens': 339}

# %%
import PIL.Image

img = PIL.Image.open('/content/rag-mechanism.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1590x837>

# %%
# !sudo apt -y -qq install tesseract-ocr libtesseract-dev

# !sudo apt-get -y -qq install poppler-utils libxml2-dev libxslt1-dev antiword unrtf poppler-utils pstotext tesseract-ocr flac ffmpeg lame libmad0 libsox-fmt-mp3 sox libjpeg-dev swig

# !pip install langchain
# Out:
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# Check if you can import the required module after installation
from langchain_community import document_loaders

# %%
import urllib
import warnings
from pathlib import Path as p
from pprint import pprint

import pandas as pd
from langchain import PromptTemplate
from langchain.chains.question_answering import load_qa_chain
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA

# Suppress warnings
warnings.filterwarnings("ignore")

# Code continues as needed...

# %%
import urllib
import warnings
from pathlib import Path as p
from pprint import pprint

import pandas as pd
from langchain import PromptTemplate
from langchain.chains.question_answering import load_qa_chain
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA

# Suppress warnings
warnings.filterwarnings("ignore")

# Code continues as needed...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(model="gemini-pro",google_api_key=GOOGLE_API_KEY,
                             temperature=0.2,convert_system_message_to_human=True)

# %%
pdf_loader = PyPDFLoader("/content/DL_Project-Report.pdf")
pages = pdf_loader.load_and_split()
print(pages[3].page_content)
# Out:
# Page | 4
#  Model design/architecture
# The architecture of the (CNN ) model used for classification embodies a sophisticated design
# aimed at effectively discerning between authentic and forged images:
# 1. Input Layer: The model begins with an input layer tailored to accommodate the image
# dimensions. Each image, resized to 128x128 pixels and consisting of three color channels
# (RGB), serves as the input to the network.
# 2. Convolutional Layers: A series of convolutional layers follow, each tasked with extracting
# increasingly complex features from the input images. These layers employ filters of size 5x5
# to perform convolutions, capturing spatial patterns such as edges and  textures. The activation
# function ReLU is applied to introduce non -linearity and enhance the model's representational
# capacity.
# 3. Pooling Layers: Interspersed among the convolutional layers are max -pooling layers, which
# ...

# %%
len(pages)
# Out:
# 10

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=1000)
context = "\n\n".join(str(p.page_content) for p in pages)
texts = text_splitter.split_text(context)

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001",google_api_key=GOOGLE_API_KEY)

# %%
vector_index = Chroma.from_texts(texts, embeddings).as_retriever(search_kwargs={"k":5})

# %%
qa_chain = RetrievalQA.from_chain_type(
    model,
    retriever=vector_index,
    return_source_documents=True

)

# %%
question = "Describe the Model design/architecture used in detail?"
result = qa_chain({"query": question})
result["result"]
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 5 is greater than number of elements in index 2, updating n_results = 2
# ...

# %%
Markdown(result["result"])
# Out:
# The architecture of the (CNN ) model used for classification embodies a sophisticated design aimed at effectively discerning between authentic and forged images:
#
# 1. Input Layer: The model begins with an input layer tailored to accommodate the image dimensions. Each image, resized to 128x128 pixels and consisting of three color channels (RGB), serves as the input to the network.
#
# 2. Convolutional Layers: A series of convolutional layers follow, each tasked with extracting increasingly complex features from the input images. These layers employ filters of size 5x5 to perform convolutions, capturing spatial patterns such as edges and textures. The activation function ReLU is applied to introduce non -linearity and enhance the model's representational capacity.
#
# ...

# %%
result["source_documents"]
# Out:
# [Document(page_content="Page | 1  \n  \n \n \n \nSchool of Interdisciplinary Engineering & Science \n(SINES)  \n \nProgram: MS Computational Science and Engineering  \n \nCourse Code:  CS-878 \nCourse Title:  Deep Learning  \nSubmitted To:  Dr. Muhammad Tariq Saeed  \n \nDEEP LEARNING PROJECT  \n \nStudent Name s: MUHAMMAD WALEED KHAN , \nSAQLAIN AYUB , M. ZAK ARIYA  \nRegistration No ’s: 451539 , 451612 , 450220  \nSubmitted On:  08-05-2024\n\nPage | 2  \n Table of Contents  \nProblem Statement  ................................ ................................ ................................ .....................  3 \nDataset Collection  ................................ ................................ ................................ ......................  3 \nModel design/architecture  ................................ ................................ ................................ ..........  4 \nPerformance comparison  ................................ ........................
# ...

# %%
template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. Keep the answer as concise as possible. Always say "thanks for asking!" at the end of the answer.
{context}
Question: {question}
Helpful Answer:"""
QA_CHAIN_PROMPT = PromptTemplate.from_template(template)# Run chain
qa_chain = RetrievalQA.from_chain_type(
    model,
    retriever=vector_index,
    return_source_documents=True,
    chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
)

# %%
question = "Describe the Multi-head attention layer in detail?"
result = qa_chain({"query": question})
result["result"]
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 5 is greater than number of elements in index 2, updating n_results = 2
# 'The provided context does not mention anything about the Multi-head attention layer, so I cannot answer this question.\nThanks for asking!'

# %%
question = "Describe the Performance comparison done in the project in detail?"
result = qa_chain({"query": question})
result["result"]
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 5 is greater than number of elements in index 2, updating n_results = 2
# 'The performance comparison in the project was done by comparing the CNN model with the benchmark models, namely KNN, MLP (Multi-Layer Perceptron), SVM (Support Vector Machine), and Gaussian Naive Bayes, based on their validation and test accuracies. The CNN model outperformed all benchmark models with significantly higher validation accuracy (88%) and lower validation loss (0.495). This indicates that the CNN model effectively captures intricate features within the data, leading to more accurate predictions. Thanks for asking!'

# %%
Markdown(result["result"])
# Out:
# The performance comparison in the project was done by comparing the CNN model with the benchmark models, namely KNN, MLP (Multi-Layer Perceptron), SVM (Support Vector Machine), and Gaussian Naive Bayes, based on their validation and test accuracies. The CNN model outperformed all benchmark models with significantly higher validation accuracy (88%) and lower validation loss (0.495). This indicates that the CNN model effectively captures intricate features within the data, leading to more accurate predictions. Thanks for asking!

# %%
question = "Describe Random forest?"
result = qa_chain({"query": question})
Markdown(result["result"])
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 5 is greater than number of elements in index 2, updating n_results = 2
# I'm sorry, but the provided context does not contain any information about Random forest. Therefore, I cannot answer your question. Thanks for asking!

# %%
question = "Describe Gaussian Naive Bayes?"
result = qa_chain({"query": question})
Markdown(result["result"])
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 5 is greater than number of elements in index 2, updating n_results = 2
# Gaussian Naive Bayes is a probabilistic machine learning algorithm that assumes that the features of the data are independent of each other. This assumption simplifies the computation of the posterior probability of a class given a set of features. Gaussian Naive Bayes is often used for text classification and spam filtering.
# Thanks for asking!
